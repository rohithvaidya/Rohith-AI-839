# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("../data/01_raw/dataset_id_106.csv")

# %%
df.head()
# Out:
#   checking_status  duration                  credit_history  \
# 0              <0        12                   existing paid
# 1     no checking        12  critical/other existing credit
# 2     no checking        12                   existing paid
# 3     no checking         6                   existing paid
# 4        0<=X<200        24                   existing paid
#
#                purpose  credit_amount savings_status employment  \
# 0             radio/tv         1680.0    500<=X<1000        >=7
# 1              new car          682.0     100<=X<500     4<=X<7
# 2  furniture/equipment         1123.0    500<=X<1000     1<=X<4
# 3              new car         3518.0           <100     1<=X<4
# 4  furniture/equipment         3069.0     100<=X<500        >=7
#
#    installment_commitment     personal_status other_parties  ...          X_2  \
# 0                       3        male mar/wid          none  ...  1684.645980
# 1                       4  female div/dep/mar          none  ...  1332.604887
# 2                       4  female div/dep/mar          none  ...  1529.809197
# 3                       2         male single     guarantor  ...  1594.967273
# 4                       4         male single          none  ...   185.695469
#
#         X_3       X_4       X_5       X_6       X_7       X_8       X_9  \
# 0  0.449565  7.102188  0.008565  0.954307  0.449565  0.610219  0.852060
# 1  0.974432  9.574619  0.974432  0.857462  0.855410  0.859526  0.352279
# 2  0.352279  3.120318  0.780444  0.899411  0.047740  0.137447  0.176330
# 3  0.047740  2.374474  0.510493  0.767080  0.484739  0.209614  0.418849
# 4  0.510493  8.670796  0.391514  0.513463  0.696148  0.995817  0.607471
#
#        X_10      y
# 0  0.738810   True
# 1  0.212032   True
# 2  0.036748  False
# 3  0.564009  False
# 4  0.819747  False
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         100 non-null    object
#  1   duration                100 non-null    int64
#  2   credit_history          100 non-null    object
#  3   purpose                 100 non-null    object
#  4   credit_amount           100 non-null    float64
#  5   savings_status          100 non-null    object
#  6   employment              100 non-null    object
#  7   installment_commitment  100 non-null    int64
#  8   personal_status         100 non-null    object
#  9   other_parties           100 non-null    object
#  10  residence_since         100 non-null    int64
#  11  property_magnitude      100 non-null    object
#  12  age                     100 non-null    int64
#  13  other_payment_plans     100 non-null    object
#  14  housing                 100 non-null    object
#  15  existing_credits        100 non-null    int64
#  16  job                     100 non-null    object
#  17  num_dependents          100 non-null    int64
#  18  own_telephone           100 non-null    object
#  19  foreign_worker          100 non-null    object
#  20  health_status           100 non-null    object
#  21  X_1                     100 non-null    float64
#  22  X_2                     100 non-null    float64
#  23  X_3                     100 non-null    float64
#  24  X_4                     100 non-null    float64
#  25  X_5                     100 non-null    float64
#  26  X_6                     100 non-null    float64
#  27  X_7                     100 non-null    float64
#  28  X_8                     100 non-null    float64
#  29  X_9                     100 non-null    float64
#  30  X_10                    100 non-null    float64
#  31  y                       100 non-null    bool
# dtypes: bool(1), float64(11), int64(6), object(14)
# memory usage: 24.4+ KB

# %%
categorical_columns = df.select_dtypes(include=["object"]).columns
print(list(categorical_columns))
# Out:
# ['checking_status', 'credit_history', 'purpose', 'savings_status', 'employment', 'personal_status', 'other_parties', 'property_magnitude', 'other_payment_plans', 'housing', 'job', 'own_telephone', 'foreign_worker', 'health_status']

# %%
for i in list(categorical_columns):
    print(df[i].value_counts())
    print("\n")
# Out:
# no checking    47
# 0<=X<200       28
# <0             17
# >=200           8
# Name: checking_status, dtype: int64
#
#
# existing paid                     55
# critical/other existing credit    28
# delayed previously                 9
# all paid                           5
# no credits/all paid                3
# Name: credit_history, dtype: int64
#
#
# radio/tv               34
# new car                23
# furniture/equipment    15
# used car                8
# business                8
# education               5
# domestic appliance      3
# repairs                 2
# other                   2
# Name: purpose, dtype: int64
#
#
# <100                52
# no known savings    21
# 100<=X<500          16
# 500<=X<1000          6
# >=1000               5
# Name: savings_status, dtype: int64
#
#
# 1<=X<4        38
# >=7           24
# 4<=X<7        20
# <1            12
# unemployed     6
# Name: employment, dtype: int64
#
#
# male single           57
# female div/dep/mar    31
# male mar/wid          11
# male div/sep           1
# Name: personal_status, dtype: int64
#
#
# none            89
# guarantor        6
# co applicant     5
# Name: other_parties, dtype: int64
#
#
# car                  35
# life insurance       30
# real estate          19
# no known property    16
# Name: property_magnitude, dtype: int64
#
#
# none      76
# stores    12
# bank      12
# Name: other_payment_plans, dtype: int64
#
#
# own         75
# rent        15
# for free    10
# Name: housing, dtype: int64
#
#
# skilled                      66
# unskilled resident           17
# high qualif/self emp/mgmt    16
# unemp/unskilled non res       1
# Name: job, dtype: int64
#
#
# none    56
# yes     44
# Name: own_telephone, dtype: int64
#
#
# yes    98
# no      2
# Name: foreign_worker, dtype: int64
#
#
# good    65
# bad     35
# Name: health_status, dtype: int64

# %%
# Doing Label encoding for features with two categories

le = LabelEncoder()
df["own_telephone"] = le.fit_transform(df["own_telephone"])
df["foreign_worker"] = le.fit_transform(df["foreign_worker"])
df["health_status"] = le.fit_transform(df["health_status"])

df["y"] = le.fit_transform(df["y"])

# %%
# Out:
# 1

# %%
# Doing Ordinal Encoding

df["savings_status"] = df["savings_status"].map(
    {"<100": 0, "no known savings": 1, "100<=X<500": 2, "500<=X<1000": 3, ">=1000": 4}
)

df["employment"] = df["employment"].map(
    {"1<=X<4": 0, ">=7": 1, "4<=X<7": 2, "<1": 3, "unemployed": 4}
)

df["checking_status"] = df["checking_status"].map(
    {"no checking": 0, "0<=X<200": 1, "<0": 2, ">=200": 3}
)

# %%
# Doing One hot encoding for features with multiple

df = pd.get_dummies(
    df,
    columns=[
        "purpose",
        "credit_history",
        "personal_status",
        "housing",
        "job",
        "other_payment_plans",
        "property_magnitude",
        "other_parties",
    ],
    drop_first=True,
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 51 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   checking_status                                100 non-null    int64
#  1   duration                                       100 non-null    int64
#  2   credit_amount                                  100 non-null    float64
#  3   savings_status                                 100 non-null    int64
#  4   employment                                     100 non-null    int64
#  5   installment_commitment                         100 non-null    int64
#  6   residence_since                                100 non-null    int64
#  7   age                                            100 non-null    int64
#  8   existing_credits                               100 non-null    int64
#  9   num_dependents                                 100 non-null    int64
#  10  own_telephone                                  100 non-null    int32
#  11  foreign_worker                                 100 non-null    int32
#  12  health_status                                  100 non-null    int32
#  13  X_1                                            100 non-null    float64
#  14  X_2                                            100 non-null    float64
#  15  X_3                                            100 non-null    float64
#  16  X_4                                            100 non-null    float64
#  17  X_5                                            100 non-null    float64
#  18  X_6                                            100 non-null    float64
#  19  X_7                                            100 non-null    float64
#  20  X_8                                            100 non-null    float64
#  21  X_9                                            100 non-null    float64
#  22  X_10                                           100 non-null    float64
#  23  y                                              100 non-null    int64
#  24  purpose_domestic appliance                     100 non-null    uint8
#  25  purpose_education                              100 non-null    uint8
#  26  purpose_furniture/equipment                    100 non-null    uint8
#  27  purpose_new car                                100 non-null    uint8
#  28  purpose_other                                  100 non-null    uint8
#  29  purpose_radio/tv                               100 non-null    uint8
#  30  purpose_repairs                                100 non-null    uint8
#  31  purpose_used car                               100 non-null    uint8
#  32  credit_history_critical/other existing credit  100 non-null    uint8
#  33  credit_history_delayed previously              100 non-null    uint8
#  34  credit_history_existing paid                   100 non-null    uint8
#  35  credit_history_no credits/all paid             100 non-null    uint8
#  36  personal_status_male div/sep                   100 non-null    uint8
#  37  personal_status_male mar/wid                   100 non-null    uint8
#  38  personal_status_male single                    100 non-null    uint8
#  39  housing_own                                    100 non-null    uint8
#  40  housing_rent                                   100 non-null    uint8
#  41  job_skilled                                    100 non-null    uint8
#  42  job_unemp/unskilled non res                    100 non-null    uint8
#  43  job_unskilled resident                         100 non-null    uint8
#  44  other_payment_plans_none                       100 non-null    uint8
#  45  other_payment_plans_stores                     100 non-null    uint8
#  46  property_magnitude_life insurance              100 non-null    uint8
#  47  property_magnitude_no known property           100 non-null    uint8
#  48  property_magnitude_real estate                 100 non-null    uint8
#  49  other_parties_guarantor                        100 non-null    uint8
#  50  other_parties_none                             100 non-null    uint8
# dtypes: float64(11), int32(3), int64(10), uint8(27)
# memory usage: 20.3 KB
